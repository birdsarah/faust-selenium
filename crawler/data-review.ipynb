# %%
import pandas as pd

# %%
DB = 'sqlite:///demo-data/crawl-data.sqlite'

# %%
df = pd.read_sql_table('crawl_requests', DB, index_col='id')
print('Request')
df.tail()
# Out:
# Request
#             visit_id crawl_id                         url
# id
# 1   -848708609247960   simple  http://localhost:8000?x=50

# %%
df = pd.read_sql_table('webext_starts', DB, index_col='id')
print('WebExt Starts')
df.tail()
# Out:
# WebExt Starts
#             visit_id crawl_id
# id
# 1   -848708609247960   simple

# %%
df = pd.read_sql_table('crawl_results', DB, index_col='id')
print('Result')
df.tail()
# Out:
# Result
#             visit_id  success
# id
# 1   -848708609247960     True

# %%
df = pd.read_sql_table('javascript', DB, index_col='id')
print('Javascript')
df.tail()
# Out:
# Javascript
#    crawl_id          visit_id                time_stamp  \
# id
# 27   simple  -848708609247960  2019-08-26T02:47:30.868Z
# 28   simple  -848708609247960  2019-08-26T02:47:30.864Z
# 29   simple  -848708609247960  2019-08-26T02:47:30.870Z
# 30   simple  -848708609247960  2019-08-26T02:47:30.868Z
# 31   simple  -848708609247960  2019-08-26T02:47:30.868Z
#
#                   top_level_url                 document_url  \
# id
# 27  http://localhost:8000/?x=50  http://localhost:8000/?x=50
# 28  http://localhost:8000/?x=50  http://localhost:8000/?x=50
# 29  http://localhost:8000/?x=50  http://localhost:8000/?x=50
# 30  http://localhost:8000/?x=50  http://localhost:8000/?x=50
# 31  http://localhost:8000/?x=50  http://localhost:8000/?x=50
#
#                                script_url  \
# id
# 27  http://localhost:8000/fingerprint2.js
# 28  http://localhost:8000/fingerprint2.js
# 29  http://localhost:8000/fingerprint2.js
# 30  http://localhost:8000/fingerprint2.js
# 31  http://localhost:8000/fingerprint2.js
#
#                   extension_session_uuid  event_ordinal  \
# id
# 27  2c3d79e6-613d-4e7d-acd5-aed5acb6ac15             31
# 28  2c3d79e6-613d-4e7d-acd5-aed5acb6ac15             21
# 29  2c3d79e6-613d-4e7d-acd5-aed5acb6ac15             39
# 30  2c3d79e6-613d-4e7d-acd5-aed5acb6ac15             36
# 31  2c3d79e6-613d-4e7d-acd5-aed5acb6ac15             32
#
#     page_scoped_event_ordinal  window_id  ...  script_line  script_col  \
# id                                        ...
# 27                         22          1  ...          694          11
# 28                         12          1  ...          676          11
# 29                         30          1  ...          708          41
# 30                         27          1  ...          704          11
# 31                         23          1  ...          695           7
#
#       func_name script_loc_eval call_stack  \
# id
# 27  getCanvasFp
# 28  getCanvasFp
# 29  getCanvasFp
# 30  getCanvasFp
# 31  getCanvasFp
#
#                                 symbol operation incognito           value  \
# id
# 27       CanvasRenderingContext2D.fill      call         0
# 28   CanvasRenderingContext2D.fillText      call         0
# 29         HTMLCanvasElement.toDataURL      call         0
# 30        CanvasRenderingContext2D.arc      call         0
# 31  CanvasRenderingContext2D.fillStyle       set         0  rgb(255,255,0)
#
#                                         arguments
# id
# 27
# 28  ["Cwm fjordbank glyphs vext quiz, ð",2,15]
# 29
# 30            [75,75,75,0,6.283185307179586,true]
# 31
#
# [5 rows x 22 columns]

# %%
df = pd.read_sql_table('javascript_cookies', DB, index_col='id')
print('Javascript cookies')
df.tail()
# Out:
# Javascript cookies
# Empty DataFrame
# Columns: [crawl_id, visit_id, time_stamp, record_type, change_cause, extension_session_uuid, event_ordinal, expiry, is_http_only, is_host_only, is_session, host, is_secure, name, path, value, same_site, first_party_domain, store_id]
# Index: []

# %%
df = pd.read_sql_table('navigations', DB, index_col='id')
print('Navigations')
df.tail()
# Out:
# Navigations
#    crawl_id          visit_id  before_navigate_event_ordinal  \
# id
# 1    simple  -848708609247960                             -1
#
#    before_navigate_time_stamp  parent_frame_id transition_qualifiers  \
# id
# 1                                           -1                    []
#
#    transition_type  committed_event_ordinal      committed_time_stamp  \
# id
# 1             link                        0  2019-08-26T02:47:30.647Z
#
#     incognito  ... tab_opener_tab_id  frame_id  window_width  window_height  \
# id             ...
# 1           0  ...                -1         0          1366            768
#
#     window_type  tab_width  tab_height  tab_cookie_store_id  \
# id
# 1        normal       1366         694      firefox-default
#
#                                     uuid                          url
# id
# 1   77d5c010-8a14-4cae-84ba-7dbd51e63bb0  http://localhost:8000/?x=50
#
# [1 rows x 24 columns]

# %%
df = pd.read_sql_table('http_requests', DB, index_col='id')
print('HTTP Requests')
df.tail()
# Out:
# HTTP Requests
#    crawl_id          visit_id                time_stamp  incognito  \
# id
# 1    simple  -848708609247960  2019-08-26T02:47:30.693Z          0
# 2    simple  -848708609247960  2019-08-26T02:47:30.727Z          0
# 3    simple  -848708609247960  2019-08-26T02:47:30.774Z          0
# 4    simple  -848708609247960  2019-08-26T02:47:30.733Z          0
#
#                   extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 1   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              1          1       1
# 2   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              3          1       1
# 3   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              7          1       1
# 4   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              5          1       1
#
#     frame_id  parent_frame_id  ...  post_body_raw  \
# id                             ...
# 1          0               -1  ...
# 2          0               -1  ...
# 3          0               -1  ...
# 4          0               -1  ...
#
#                                               headers is_XHR is_full_page  \
# id
# 1   [["Host","localhost:8000"],["User-Agent","Mozi...      0            1
# 2   [["Host","127.0.0.1:7799"],["User-Agent","Mozi...      0            1
# 3   [["Host","localhost:8000"],["User-Agent","Mozi...      0            1
# 4   [["Host","127.0.0.1:7799"],["User-Agent","Mozi...      0            1
#
#    is_frame_load      triggering_origin         loading_origin  \
# id
# 1              0  http://localhost:8000  http://localhost:8000
# 2              0  http://localhost:8000  http://localhost:8000
# 3              0  http://localhost:8000  http://localhost:8000
# 4              0  http://localhost:8000  http://localhost:8000
#
#                    loading_href  resource_type  frame_ancestors
# id
# 1   http://localhost:8000/?x=50         script               []
# 2   http://localhost:8000/?x=50      websocket               []
# 3   http://localhost:8000/?x=50          image               []
# 4   http://localhost:8000/?x=50      websocket               []
#
# [4 rows x 26 columns]

# %%
df = pd.read_sql_table('http_responses', DB, index_col='id')
print('HTTP Responses')
df.tail()
# Out:
# HTTP Responses
#    crawl_id          visit_id                time_stamp  incognito  \
# id
# 1    simple  -848708609247960  2019-08-26T02:47:30.736Z          0
# 2    simple  -848708609247960  2019-08-26T02:47:30.730Z          0
# 3    simple  -848708609247960  2019-08-26T02:47:30.710Z          0
# 4    simple  -848708609247960  2019-08-26T02:47:30.780Z          0
#
#                   extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 1   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              6          1       1
# 2   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              4          1       1
# 3   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              2          1       1
# 4   2c3d79e6-613d-4e7d-acd5-aed5acb6ac15              8          1       1
#
#     frame_id  request_id  is_cached                                    url  \
# id
# 1          0          17          0                  ws://127.0.0.1:7799/2
# 2          0          16          0                  ws://127.0.0.1:7799/1
# 3          0          15          0  http://localhost:8000/fingerprint2.js
# 4          0          18          0      http://localhost:8000/favicon.ico
#
#    method response_status              response_status_text  \
# id
# 1     GET             101  HTTP/1.1 101 Switching Protocols
# 2     GET             101  HTTP/1.1 101 Switching Protocols
# 3     GET             200                   HTTP/1.0 200 OK
# 4     GET             404       HTTP/1.0 404 File not found
#
#                                               headers location content_hash
# id
# 1   [["Upgrade","websocket"],["Connection","Upgrad...
# 2   [["Upgrade","websocket"],["Connection","Upgrad...
# 3   [["Server","SimpleHTTP/0.6 Python/3.7.3"],["Da...
# 4   [["Server","SimpleHTTP/0.6 Python/3.7.3"],["Da...

# %%
df = pd.read_sql_table('http_redirects', DB, index_col='id')
print('HTTP Redirects')
df.tail()
# Out:
# HTTP Redirects
# Empty DataFrame
# Columns: [crawl_id, visit_id, time_stamp, extension_session_uuid, event_ordinal, window_id, tab_id, frame_id, old_request_id, new_request_id, old_request_url, new_request_url, response_status, response_status_text]
# Index: []

# %%
df = pd.read_sql_table('logs', DB, index_col='id')
print('Logs')
df.tail()
# Out:
# Logs
#               timestamp  msecs          name  level  \
# id
# 13  2019-08-25 21:47:30    582       crawler   INFO
# 14  2019-08-25 21:47:33    889       crawler   INFO
# 15  2019-08-25 21:47:30    611  WebExtension  DEBUG
# 16  2019-08-25 21:47:30    671       crawler   INFO
# 17  2019-08-25 21:47:27    460       crawler   INFO
#
#                                               message exception stack
# id
# 13          OPENWPM: OpenWPM Firefox extension loaded      None  None
# 14  GECKODRIVER 1566787653832\tMarionette\tINFO\tS...      None  None
# 15                 Navigation instrumentation enabled      None  None
# 16  GECKODRIVER 1566787650446\tMarionette\tWARN\tT...      None  None
# 17  OPENWPM: Browser Binary Path /home/bird/Dev/bi...      None  None
