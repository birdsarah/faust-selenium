# %%
import json
import pandas as pd

# %%
DB = 'sqlite:///demo-data/crawl-data.sqlite'

# %%
df = pd.read_sql_table('crawl_requests', DB, index_col='id')
print('Request')
df.tail()
# Out:
# Request
#               visit_id     crawl_id                        url
# id
# 196   -450136329002138  -1298079119       http://pompommag.com
# 197  -3707695989448070  -1298079119  http://lelibrepenseur.org
# 198   1548315351639331  -1298079119         http://phusing.com
# 199  -2657662661427902  -1298079119      http://inhorgenta.com
# 200   3854818031223403  -1298079119             http://msgm.it

# %%
df = pd.read_sql_table('webext_starts', DB, index_col='id')
print('WebExt Starts')
df.tail()
# Out:
# WebExt Starts
#               visit_id     crawl_id
# id
# 171   -423353301499794  -1298079119
# 172   1556491984238057  -1298079119
# 173   -699856817323781  -1298079119
# 174  -2029113851687025  -1298079119
# 175    482485790069795  -1298079119

# %%
df = pd.read_sql_table('crawl_results', DB, index_col='id')
print('Result')
df.tail()
# Out:
# Result
#               visit_id  success
# id
# 196  -4225130431259146     True
# 197   -955931730315173     True
# 198   1548315351639331     True
# 199  -3275768853329014     True
# 200   3037925188248738     True

# %%
df.success.value_counts()
# Out:
# True     196
# False      4
# Name: success, dtype: int64

# %%
# Failed crawls

df[df.success == False].merge(pd.read_sql_table('crawl_requests', DB, index_col='id'), on='visit_id')
# Out:
#             visit_id  success     crawl_id                              url
# 0    425497880905360    False  -1298079119        http://equidadpoblana.com
# 1   1417692719384539    False  -1298079119                 http://h3bpm.com
# 2   4170193717080205    False  -1298079119  http://stevesimms.wordpress.com
# 3  -3308860931062777    False  -1298079119             http://bimebartar.ir

# %%
df = pd.read_sql_table('javascript', DB, index_col='id')
print('Javascript')
df.tail()
# Out:
# Javascript
#           crawl_id           visit_id                time_stamp  \
# id
# 55534  -1298079119  -3275768853329014  2019-08-27T06:55:18.095Z
# 55535  -1298079119  -3275768853329014  2019-08-27T06:55:18.095Z
# 55536  -1298079119  -3275768853329014  2019-08-27T06:55:18.096Z
# 55537  -1298079119  -3275768853329014  2019-08-27T06:55:18.098Z
# 55538  -1298079119  -3275768853329014  2019-08-27T06:55:18.095Z
#
#                       top_level_url  \
# id
# 55534  https://www.gls-spain.es/en/
# 55535  https://www.gls-spain.es/en/
# 55536  https://www.gls-spain.es/en/
# 55537  https://www.gls-spain.es/en/
# 55538  https://www.gls-spain.es/en/
#
#                                             document_url  \
# id
# 55534  https://www.google.com/recaptcha/api2/anchor?a...
# 55535  https://www.google.com/recaptcha/api2/anchor?a...
# 55536  https://www.google.com/recaptcha/api2/anchor?a...
# 55537  https://www.google.com/recaptcha/api2/anchor?a...
# 55538  https://www.google.com/recaptcha/api2/anchor?a...
#
#                                               script_url  \
# id
# 55534  https://www.gstatic.com/recaptcha/api2/v156559...
# 55535  https://www.gstatic.com/recaptcha/api2/v156559...
# 55536  https://www.gstatic.com/recaptcha/api2/v156559...
# 55537  https://www.gstatic.com/recaptcha/api2/v156559...
# 55538  https://www.gstatic.com/recaptcha/api2/v156559...
#
#                      extension_session_uuid  event_ordinal  \
# id
# 55534  c2672e36-f683-4978-9fe4-5ca10510da56            264
# 55535  c2672e36-f683-4978-9fe4-5ca10510da56            265
# 55536  c2672e36-f683-4978-9fe4-5ca10510da56            268
# 55537  c2672e36-f683-4978-9fe4-5ca10510da56            271
# 55538  c2672e36-f683-4978-9fe4-5ca10510da56            266
#
#        page_scoped_event_ordinal  window_id  ...  script_line  script_col  \
# id                                           ...
# 55534                         30          1  ...          309         149
# 55535                         31          1  ...          308         424
# 55536                         34          1  ...          309         149
# 55537                         37          1  ...          308         353
# 55538                         32          1  ...          309         149
#
#       func_name script_loc_eval call_stack                  symbol operation  \
# id
# 55534        cZ                              window.sessionStorage       get
# 55535        $3                             window.Storage.getItem      call
# 55536        cZ                              window.sessionStorage       get
# 55537        jR                             window.Storage.setItem      call
# 55538        cZ                              window.sessionStorage       get
#
#       incognito                                              value  \
# id
# 55534         0  {"rc::c":"BGtiyoBv2fdbXb46eqKNc62qLfNi_4X92ufS...
# 55535         0
# 55536         0  {"rc::c":"BGtiyoBv2fdbXb46eqKNc62qLfNi_4X92ufS...
# 55537         0
# 55538         0  {"rc::c":"BGtiyoBv2fdbXb46eqKNc62qLfNi_4X92ufS...
#
#                                                arguments
# id
# 55534
# 55535                                          ["rc::c"]
# 55536
# 55537  ["rc::c","BgYWFy9pEJ9HFqo7NOnrNqGvb_dVOrQhjpVX...
# 55538
#
# [5 rows x 22 columns]

# %%
df = pd.read_sql_table('javascript_cookies', DB, index_col='id')
print('Javascript cookies')
df.tail()
# Out:
# Javascript cookies
#          crawl_id           visit_id                time_stamp  \
# id
# 9815  -1298079119  -3275768853329014  2019-08-27T06:55:16.717Z
# 9816  -1298079119  -3275768853329014  2019-08-27T06:55:16.757Z
# 9817  -1298079119  -3275768853329014  2019-08-27T06:55:16.762Z
# 9818  -1298079119  -3275768853329014  2019-08-27T06:55:16.756Z
# 9819  -1298079119  -3275768853329014  2019-08-27T06:55:17.926Z
#
#            record_type change_cause                extension_session_uuid  \
# id
# 9815  added-or-changed     explicit  c2672e36-f683-4978-9fe4-5ca10510da56
# 9816  added-or-changed     explicit  c2672e36-f683-4978-9fe4-5ca10510da56
# 9817  added-or-changed     explicit  c2672e36-f683-4978-9fe4-5ca10510da56
# 9818  added-or-changed     explicit  c2672e36-f683-4978-9fe4-5ca10510da56
# 9819  added-or-changed     explicit  c2672e36-f683-4978-9fe4-5ca10510da56
#
#       event_ordinal                    expiry  is_http_only  is_host_only  \
# id
# 9815            128  2019-08-28T06:55:16.000Z             0             1
# 9816            130  2019-08-28T06:55:16.000Z             0             0
# 9817            131  2019-08-27T06:56:16.000Z             0             0
# 9818            129  2021-08-26T06:55:16.000Z             0             0
# 9819            258  2020-02-26T06:55:17.000Z             1             0
#
#       is_session              host  is_secure                      name path  \
# id
# 9815           0  www.gls-spain.es          0                    visits    /
# 9816           0     .gls-spain.es          0                      _gid    /
# 9817           0     .gls-spain.es          0  _gat_gtag_UA_117514546_1    /
# 9818           0     .gls-spain.es          0                       _ga    /
# 9819           0       .google.com          0                       NID    /
#
#                                                   value       same_site  \
# id
# 9815                                                  1  no_restriction
# 9816                          GA1.2.13769748.1566888917  no_restriction
# 9817                                                  1  no_restriction
# 9818                          GA1.2.41423215.1566888917  no_restriction
# 9819  188=XVNEtlWjF309oHxD30ZxrZS81vMEYW84BEnPaDTmIB...  no_restriction
#
#      first_party_domain         store_id
# id
# 9815                     firefox-default
# 9816                     firefox-default
# 9817                     firefox-default
# 9818                     firefox-default
# 9819                     firefox-default

# %%
df = pd.read_sql_table('navigations', DB, index_col='id')
print('Navigations')
df.tail()
# Out:
# Navigations
#          crawl_id           visit_id  before_navigate_event_ordinal  \
# id
# 1829  -1298079119  -3275768853329014                             -1
# 1830  -1298079119  -3275768853329014                            195
# 1831  -1298079119  -3275768853329014                            214
# 1832  -1298079119  -3275768853329014                            219
# 1833  -1298079119  -3275768853329014                            260
#
#      before_navigate_time_stamp  parent_frame_id transition_qualifiers  \
# id
# 1829                                          -1   ["server_redirect"]
# 1830   2019-08-27T06:55:16.931Z                0                    []
# 1831   2019-08-27T06:55:17.127Z                0                    []
# 1832   2019-08-27T06:55:17.216Z       4294967301                    []
# 1833   2019-08-27T06:55:17.956Z                0                    []
#
#      transition_type  committed_event_ordinal      committed_time_stamp  \
# id
# 1829            link                        6  2019-08-27T06:55:14.271Z
# 1830   auto_subframe                      196  2019-08-27T06:55:16.932Z
# 1831   auto_subframe                      215  2019-08-27T06:55:17.127Z
# 1832   auto_subframe                      220  2019-08-27T06:55:17.217Z
# 1833   auto_subframe                      261  2019-08-27T06:55:17.957Z
#
#       incognito  ... tab_opener_tab_id    frame_id  window_width  \
# id               ...
# 1829          0  ...                -1           0          1366
# 1830          0  ...                -1  4294967301          1366
# 1831          0  ...                -1  4294967304          1366
# 1832          0  ...                -1  4294967306          1366
# 1833          0  ...                -1  4294967308          1366
#
#       window_height  window_type  tab_width  tab_height  tab_cookie_store_id  \
# id
# 1829            768       normal       1366         694      firefox-default
# 1830            768       normal       1366         694      firefox-default
# 1831            768       normal       1366         694      firefox-default
# 1832            768       normal       1366         694      firefox-default
# 1833            768       normal       1366         694      firefox-default
#
#                                       uuid  \
# id
# 1829  ad5d5145-d441-43ed-aba5-9909d93b0de2
# 1830  ee74c881-367f-4b4a-9c97-befe586f4f45
# 1831  d4d0c90a-bde3-4f60-b9fc-5454dc540bfa
# 1832  6e39c1aa-e297-4719-b5dd-cb1db2432a09
# 1833  e45307d1-f453-4103-b6e5-f6480c403bfc
#
#                                                     url
# id
# 1829                       https://www.gls-spain.es/en/
# 1830  https://www.google.com/recaptcha/api2/anchor?a...
# 1831                                        about:blank
# 1832                                        about:blank
# 1833                                        about:blank
#
# [5 rows x 24 columns]

# %%
df = pd.read_sql_table('http_requests', DB, index_col='id')
print('HTTP Requests')
df.tail()
# Out:
# HTTP Requests
#           crawl_id           visit_id                time_stamp  incognito  \
# id
# 24488  -1298079119  -3275768853329014  2019-08-27T06:55:17.016Z          0
# 24489  -1298079119  -3275768853329014  2019-08-27T06:55:17.426Z          0
# 24490  -1298079119  -3275768853329014  2019-08-27T06:55:17.107Z          0
# 24491  -1298079119  -3275768853329014  2019-08-27T06:55:17.016Z          0
# 24492  -1298079119  -3275768853329014  2019-08-27T06:55:17.585Z          0
#
#                      extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 24488  c2672e36-f683-4978-9fe4-5ca10510da56            201          1       1
# 24489  c2672e36-f683-4978-9fe4-5ca10510da56            225          1       1
# 24490  c2672e36-f683-4978-9fe4-5ca10510da56            210          1       1
# 24491  c2672e36-f683-4978-9fe4-5ca10510da56            202          1       1
# 24492  c2672e36-f683-4978-9fe4-5ca10510da56            255          1       1
#
#          frame_id  parent_frame_id  ... post_body_raw  \
# id                                  ...
# 24488  4294967301                0  ...
# 24489           0               -1  ...
# 24490  4294967301                0  ...
# 24491  4294967301                0  ...
# 24492  4294967301                0  ...
#
#                                                  headers is_XHR is_full_page  \
# id
# 24488  [["Host","www.gstatic.com"],["User-Agent","Moz...      0            0
# 24489  [["Host","www.gstatic.com"],["User-Agent","Moz...      0            1
# 24490  [["Host","www.gstatic.com"],["User-Agent","Moz...      0            0
# 24491  [["Host","www.gstatic.com"],["User-Agent","Moz...      0            0
# 24492  [["Host","www.google.com"],["User-Agent","Mozi...      1            0
#
#       is_frame_load        triggering_origin          loading_origin  \
# id
# 24488             0   https://www.google.com  https://www.google.com
# 24489             0   https://www.google.com  https://www.google.com
# 24490             0  https://www.gstatic.com  https://www.google.com
# 24491             0   https://www.google.com  https://www.google.com
# 24492             0   https://www.google.com  https://www.google.com
#
#                                             loading_href   resource_type  \
# id
# 24488  https://www.google.com/recaptcha/api2/anchor?a...      stylesheet
# 24489  https://www.google.com/recaptcha/api2/webworke...          script
# 24490  https://www.google.com/recaptcha/api2/anchor?a...           image
# 24491  https://www.google.com/recaptcha/api2/anchor?a...          script
# 24492  https://www.google.com/recaptcha/api2/anchor?a...  xmlhttprequest
#
#                                          frame_ancestors
# id
# 24488  [{"frameId":0,"url":"https://www.gls-spain.es/...
# 24489                                          undefined
# 24490  [{"frameId":0,"url":"https://www.gls-spain.es/...
# 24491  [{"frameId":0,"url":"https://www.gls-spain.es/...
# 24492  [{"frameId":0,"url":"https://www.gls-spain.es/...
#
# [5 rows x 26 columns]

# %%
df = pd.read_sql_table('http_responses', DB, index_col='id')
print('HTTP Responses')
df.tail()
# Out:
# HTTP Responses
#           crawl_id           visit_id                time_stamp  incognito  \
# id
# 22625  -1298079119  -3275768853329014  2019-08-27T06:55:16.986Z          0
# 22626  -1298079119  -3275768853329014  2019-08-27T06:55:17.248Z          0
# 22627  -1298079119  -3275768853329014  2019-08-27T06:55:17.226Z          0
# 22628  -1298079119  -3275768853329014  2019-08-27T06:55:17.373Z          0
# 22629  -1298079119  -3275768853329014  2019-08-27T06:55:17.945Z          0
#
#                      extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 22625  c2672e36-f683-4978-9fe4-5ca10510da56            200          1       1
# 22626  c2672e36-f683-4978-9fe4-5ca10510da56            222          1       1
# 22627  c2672e36-f683-4978-9fe4-5ca10510da56            221          1       1
# 22628  c2672e36-f683-4978-9fe4-5ca10510da56            224          1       1
# 22629  c2672e36-f683-4978-9fe4-5ca10510da56            259          1       1
#
#          frame_id request_id  is_cached  \
# id
# 22625           0         79          0
# 22626  4294967301         88          0
# 22627           0         83          0
# 22628  4294967301         87          0
# 22629  4294967301         90          0
#
#                                                      url method  \
# id
# 22625  https://www.gls-spain.es/wp-content/plugins/ml...    GET
# 22626  https://www.google.com/recaptcha/api2/webworke...    GET
# 22627  https://www.gls-spain.es/wp-content/themes/asm...    GET
# 22628  https://fonts.gstatic.com/s/roboto/v18/KFOlCnq...    GET
# 22629  https://www.google.com/recaptcha/api2/reload?k...   POST
#
#       response_status response_status_text  \
# id
# 22625             200      HTTP/1.1 200 OK
# 22626             200      HTTP/2.0 200 OK
# 22627             200      HTTP/1.1 200 OK
# 22628             200      HTTP/2.0 200 OK
# 22629             200      HTTP/2.0 200 OK
#
#                                                  headers location content_hash
# id
# 22625  [["Date","Tue, 27 Aug 2019 06:54:05 GMT"],["Se...
# 22626  [["expires","Tue, 27 Aug 2019 06:55:17 GMT"],[...
# 22627  [["Date","Tue, 27 Aug 2019 06:54:06 GMT"],["Se...
# 22628  [["accept-ranges","bytes"],["content-type","fo...
# 22629  [["p3p","CP=\"This is not a P3P policy! See g....

# %%
df = pd.read_sql_table('http_redirects', DB, index_col='id')
print('HTTP Redirects')
df.tail()
# Out:
# HTTP Redirects
#          crawl_id           visit_id                time_stamp  incognito  \
# id
# 2945  -1298079119   3037925188248738  2019-08-27T06:55:01.526Z          0
# 2946  -1298079119   3037925188248738  2019-08-27T06:55:01.669Z          0
# 2947  -1298079119  -3275768853329014  2019-08-27T06:55:12.608Z          0
# 2948  -1298079119  -3275768853329014  2019-08-27T06:55:13.476Z          0
# 2949  -1298079119  -3275768853329014  2019-08-27T06:55:16.847Z          0
#
#                     extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 2945  42fbd8ce-b360-42fb-aedd-45758c4879d0            202          1       1
# 2946  42fbd8ce-b360-42fb-aedd-45758c4879d0            262          1       1
# 2947  c2672e36-f683-4978-9fe4-5ca10510da56              1          1       1
# 2948  c2672e36-f683-4978-9fe4-5ca10510da56              3          1       1
# 2949  c2672e36-f683-4978-9fe4-5ca10510da56            134          1       1
#
#       frame_id old_request_id new_request_id  \
# id
# 2945         0             59           None
# 2946         0             85           None
# 2947         0             14           None
# 2948         0             14           None
# 2949         0             78           None
#
#                                         old_request_url  \
# id
# 2945  http://roomimg.stream.highwebmedia.com/ri/live...
# 2946  http://roomimg.stream.highwebmedia.com/ri/lore...
# 2947                               http://gls-spain.es/
# 2948                          https://www.gls-spain.es/
# 2949  https://www.google-analytics.com/r/collect?v=1...
#
#                                         new_request_url response_status  \
# id
# 2945  https://roomimg.stream.highwebmedia.com/ri/liv...             301
# 2946  https://roomimg.stream.highwebmedia.com/ri/lor...             301
# 2947                          https://www.gls-spain.es/             301
# 2948                       https://www.gls-spain.es/en/             302
# 2949  https://stats.g.doubleclick.net/r/collect?v=1&...             302
#
#                 response_status_text
# id
# 2945  HTTP/1.1 301 Moved Permanently
# 2946  HTTP/1.1 301 Moved Permanently
# 2947  HTTP/1.1 301 Moved Permanently
# 2948              HTTP/1.1 302 Found
# 2949              HTTP/2.0 302 Found

# %%
df = pd.read_sql_table('logs', DB, index_col='id')
print('Logs')
df['timestamp'] = pd.to_datetime(df.timestamp)
df.tail()
# Out:
# Logs
#                timestamp  msecs     name level  \
# id
# 4213 2019-08-27 01:55:22    658  crawler  INFO
# 4214 2019-08-27 01:55:12     46  crawler  INFO
# 4215 2019-08-27 01:55:08    990  crawler  INFO
# 4216 2019-08-27 01:55:12    111  crawler  INFO
# 4217 2019-08-27 01:55:22    602  crawler  INFO
#
#                                                 message exception stack
# id
# 4213  GECKODRIVER 1566888922607\tMarionette\tINFO\tS...      None  None
# 4214  OPENWPM: Browser Profile Path /tmp/rust_mozpro...      None  None
# 4215  OPENWPM: Browser Binary Path /home/bird/Dev/bi...      None  None
# 4216          OPENWPM: OpenWPM Firefox extension loaded      None  None
# 4217            Message: Successful waiting completed\n      None  None

# %%
# for message in df[df.message.str.startswith('GECKODRIVER')].message.values:
#    print(message)

# %% [markdown]
# ## Time to do parallelized crawl of 200 sites

# %%
df.timestamp.max() - df.timestamp.min()
# Out:
# Timedelta('0 days 00:21:48')

# %% [markdown]
# ----
#
# Pull out deliberately awkward sites for crawl. These are a list of sites known to set javascript cookies

# %%
urls_with_js_cookies = pd.read_csv('/home/bird/Data/unique_urls_crawl.csv.gz', usecols=[1], names=['url'])
urls_with_js_cookies = urls_with_js_cookies.drop_duplicates()
urls_with_js_cookies.head()
# Out:
#                                       url
# 0           http://xn--cckr8mka9bt9h.shop
# 1  http://xn--u9jwfrb8ebi5a3tzee8630s.com
# 2  http://xn--zck9awe6d0523auwbp4rs9t.com
# 3                http://yoshida-shoin.com
# 4                 http://yoshinomayumi.jp

# %%
len(urls_with_js_cookies)
# Out:
# 8145

# %%
with open('sample_of_js_cookies_sites_200.csv', 'w') as f:
    f.write(json.dumps(urls_with_js_cookies.url.sample(n=200).to_list()))

# %%
# test load
urls = json.load(open('sample_of_js_cookies_sites_200.csv', 'r'))
# urls[0:5]
