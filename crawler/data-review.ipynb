# %%
import json
import pandas as pd

# %%
DB = 'sqlite:///demo-data/crawl-data.sqlite'

# %%
df = pd.read_sql_table('crawl_requests', DB, index_col='id')
print('Request')
df.tail()
# Out:
# Request
#               visit_id     crawl_id                        url
# id
# 196   -450136329002138  -1298079119       http://pompommag.com
# 197  -3707695989448070  -1298079119  http://lelibrepenseur.org
# 198   1548315351639331  -1298079119         http://phusing.com
# 199  -2657662661427902  -1298079119      http://inhorgenta.com
# 200   3854818031223403  -1298079119             http://msgm.it

# %%
df = pd.read_sql_table('webext_starts', DB, index_col='id')
print('WebExt Starts')
df.tail()
# Out:
# WebExt Starts
#              visit_id     crawl_id
# id
# 85     13236046542628  -1298079119
# 86  -3934546314698283  -1298079119
# 87  -1626793058775822  -1298079119
# 88  -2009802813508471  -1298079119
# 89   1088142751004038  -1298079119

# %%
df = pd.read_sql_table('crawl_results', DB, index_col='id')
print('Result')
df.tail()
# Out:
# Result
#              visit_id  success
# id
# 76  -4100088645745892     True
# 77   -154949039953560     True
# 78   4276925708125917     True
# 79  -3165709383097017     True
# 80  -3937286538093254     True

# %%
df.success.value_counts()
# Out:
# True    80
# Name: success, dtype: int64

# %%
df = pd.read_sql_table('javascript', DB, index_col='id')
print('Javascript')
df.tail()
# Out:
# Javascript
#           crawl_id          visit_id                time_stamp  \
# id
# 23894  -1298079119  3544908204334844  2019-08-27T06:40:01.999Z
# 23895  -1298079119  3544908204334844  2019-08-27T06:40:02.001Z
# 23896  -1298079119  3544908204334844  2019-08-27T06:40:02.002Z
# 23897  -1298079119  3544908204334844  2019-08-27T06:40:02.029Z
# 23898  -1298079119  3544908204334844  2019-08-27T06:40:02.004Z
#
#                        top_level_url  \
# id
# 23894  https://snowdonrailway.co.uk/
# 23895  https://snowdonrailway.co.uk/
# 23896  https://snowdonrailway.co.uk/
# 23897  https://snowdonrailway.co.uk/
# 23898  https://snowdonrailway.co.uk/
#
#                                             document_url  \
# id
# 23894                      https://snowdonrailway.co.uk/
# 23895                      https://snowdonrailway.co.uk/
# 23896                      https://snowdonrailway.co.uk/
# 23897  https://platform.twitter.com/widgets/widget_if...
# 23898                      https://snowdonrailway.co.uk/
#
#                                               script_url  \
# id
# 23894      https://www.google-analytics.com/analytics.js
# 23895      https://www.google-analytics.com/analytics.js
# 23896      https://www.google-analytics.com/analytics.js
# 23897  https://platform.twitter.com/widgets/widget_if...
# 23898      https://www.google-analytics.com/analytics.js
#
#                      extension_session_uuid  event_ordinal  \
# id
# 23894  6a36f680-0a21-422d-965f-67c6375b7985            165
# 23895  6a36f680-0a21-422d-965f-67c6375b7985            178
# 23896  6a36f680-0a21-422d-965f-67c6375b7985            181
# 23897  6a36f680-0a21-422d-965f-67c6375b7985            198
# 23898  6a36f680-0a21-422d-965f-67c6375b7985            190
#
#        page_scoped_event_ordinal  window_id  ...  script_line  script_col  \
# id                                           ...
# 23894                         52          1  ...           19          38
# 23895                         65          1  ...           19         482
# 23896                         68          1  ...           19         457
# 23897                          1          1  ...            5        2864
# 23898                         77          1  ...           19          38
#
#       func_name script_loc_eval  \
# id
# 23894        Ca
# 23895        zc
# 23896        zc
# 23897
# 23898        Ca
#
#                                               call_stack  \
# id
# 23894  Ca@https://www.google-analytics.com/analytics....
# 23895  zc@https://www.google-analytics.com/analytics....
# 23896  zc@https://www.google-analytics.com/analytics....
# 23897
# 23898  Ca@https://www.google-analytics.com/analytics....
#
#                            symbol operation incognito  \
# id
# 23894      window.document.cookie       get         0
# 23895      window.document.cookie       get         0
# 23896      window.document.cookie       get         0
# 23897  window.navigator.userAgent       get         0
# 23898      window.document.cookie       get         0
#
#                                                    value  arguments
# id
# 23894  xkiagSmfPpRIzMcO=6ypmJXcZ%5DGwoSsM%2A; YhQZrdi...
# 23895  xkiagSmfPpRIzMcO=6ypmJXcZ%5DGwoSsM%2A; YhQZrdi...
# 23896  xkiagSmfPpRIzMcO=6ypmJXcZ%5DGwoSsM%2A; YhQZrdi...
# 23897  Mozilla/5.0 (X11; Linux x86_64; rv:68.0) Gecko...
# 23898  xkiagSmfPpRIzMcO=6ypmJXcZ%5DGwoSsM%2A; YhQZrdi...
#
# [5 rows x 22 columns]

# %%
df.head(1)
# Out:
#        crawl_id           visit_id                time_stamp  \
# id
# 1   -1298079119  -1322665585676754  2019-08-27T06:33:39.373Z
#
#            top_level_url          document_url  \
# id
# 1   http://bitcoin.info/  http://bitcoin.info/
#
#                                         script_url  \
# id
# 1   https://cdn.onesignal.com/sdks/OneSignalSDK.js
#
#                   extension_session_uuid  event_ordinal  \
# id
# 1   341e4d92-07d3-46d7-ae10-498cc9ec0878            168
#
#     page_scoped_event_ordinal  window_id  ...  script_line  script_col  \
# id                                        ...
# 1                           1          1  ...            1        2050
#
#          func_name script_loc_eval call_stack               symbol operation  \
# id
# 1   n</e.shouldLog                             window.localStorage       get
#
#    incognito value  arguments
# id
# 1          0    {}
#
# [1 rows x 22 columns]

# %%
df = pd.read_sql_table('javascript_cookies', DB, index_col='id')
print('Javascript cookies')
df.tail()
# Out:
# Javascript cookies
#          crawl_id           visit_id                time_stamp  \
# id
# 10435  -381328783  -2318928383487469  2019-08-27T05:16:32.042Z
# 10436  -381328783  -2318928383487469  2019-08-27T05:16:32.071Z
# 10437  -381328783  -2318928383487469  2019-08-27T05:16:32.075Z
# 10438  -381328783  -2318928383487469  2019-08-27T05:16:32.081Z
# 10439  -381328783  -2318928383487469  2019-08-27T05:16:32.095Z
#
#             record_type change_cause                extension_session_uuid  \
# id
# 10435           deleted    overwrite  026bee9b-f3d7-48d0-ac13-f74a8332dd4f
# 10436  added-or-changed     explicit  026bee9b-f3d7-48d0-ac13-f74a8332dd4f
# 10437  added-or-changed     explicit  026bee9b-f3d7-48d0-ac13-f74a8332dd4f
# 10438           deleted    overwrite  026bee9b-f3d7-48d0-ac13-f74a8332dd4f
# 10439           deleted    overwrite  026bee9b-f3d7-48d0-ac13-f74a8332dd4f
#
#        event_ordinal                    expiry  is_http_only  is_host_only  \
# id
# 10435            290  2020-02-26T05:16:31.000Z             1             0
# 10436            297  2020-02-26T05:16:31.000Z             1             0
# 10437            299  2020-02-26T05:16:31.000Z             1             0
# 10438            301  2020-02-26T05:16:31.000Z             1             0
# 10439            309  2020-02-26T05:16:32.000Z             1             0
#
#        is_session          host  is_secure name path  \
# id
# 10435           0  .blogger.com          0  NID    /
# 10436           0  .blogger.com          0  NID    /
# 10437           0  .blogger.com          0  NID    /
# 10438           0  .blogger.com          0  NID    /
# 10439           0  .blogger.com          0  NID    /
#
#                                                    value       same_site  \
# id
# 10435  188=Hz964ok9zmW_hS-lsSwIqy9OzUk0GCW9tW0lM0APF6...  no_restriction
# 10436  188=UHcavQj1SBa5XFpjzGAWI2kwWmi4SkYuvAlUlUJMdb...  no_restriction
# 10437  188=fqfGw6ZWbTWnpAI4Y4ScVSb2Fb2lUmqpMGeMizpG_u...  no_restriction
# 10438  188=e5rOSDq6vHcdjyfd_4NnII9pp6-1JB8KZp23wMMiZK...  no_restriction
# 10439  188=OQ3duRNsRIo1MbHsCP2YrsdtMgQhehZAijV2cvJdsq...  no_restriction
#
#       first_party_domain         store_id
# id
# 10435                     firefox-default
# 10436                     firefox-default
# 10437                     firefox-default
# 10438                     firefox-default
# 10439                     firefox-default

# %%
df = pd.read_sql_table('navigations', DB, index_col='id')
print('Navigations')
df.tail()
# Out:
# Navigations
#         crawl_id           visit_id  before_navigate_event_ordinal  \
# id
# 1887  -381328783     23535961138562                            169
# 1888  -381328783  -2318928383487469                             86
# 1889  -381328783     23535961138562                            532
# 1890  -381328783  -2318928383487469                            231
# 1891  -381328783  -2318928383487469                             94
#
#      before_navigate_time_stamp  parent_frame_id transition_qualifiers  \
# id
# 1887   2019-08-27T05:15:50.612Z                0                    []
# 1888   2019-08-27T05:16:30.984Z                0                    []
# 1889   2019-08-27T05:15:52.332Z                0                    []
# 1890   2019-08-27T05:16:31.524Z                0                    []
# 1891   2019-08-27T05:16:31.001Z                0                    []
#
#      transition_type  committed_event_ordinal      committed_time_stamp  \
# id
# 1887   auto_subframe                      170  2019-08-27T05:15:50.613Z
# 1888   auto_subframe                       87  2019-08-27T05:16:30.985Z
# 1889   auto_subframe                      533  2019-08-27T05:15:52.332Z
# 1890   auto_subframe                      232  2019-08-27T05:16:31.524Z
# 1891   auto_subframe                       95  2019-08-27T05:16:31.003Z
#
#       incognito  ... tab_opener_tab_id    frame_id  window_width  \
# id               ...
# 1887          0  ...                -1  4294967301          1366
# 1888          0  ...                -1  4294967304          1366
# 1889          0  ...                -1  4294967310          1366
# 1890          0  ...                -1  4294967341          1366
# 1891          0  ...                -1  4294967308          1366
#
#       window_height  window_type  tab_width  tab_height  tab_cookie_store_id  \
# id
# 1887            768       normal       1366         694      firefox-default
# 1888            768       normal       1366         694      firefox-default
# 1889            768       normal       1366         694      firefox-default
# 1890            768       normal       1366         694      firefox-default
# 1891            768       normal       1366         694      firefox-default
#
#                                       uuid  \
# id
# 1887  dff8eebd-c4c8-4f99-88a7-4badbcbf3921
# 1888  e9c1570b-48fd-4c68-87ba-925e1f69a4a5
# 1889  1dbc6ad2-152f-4e2f-9140-81d7dc472675
# 1890  dab8d377-8cd0-46ff-8b9f-d9877fe765b5
# 1891  e1514537-7958-4fc9-a742-e7880bc9a0f5
#
#                                                     url
# id
# 1887  https://8615813.fls.doubleclick.net/activityi;...
# 1888  https://www.blogger.com/blog-post-reactions.g?...
# 1889                       https://www.facebook.com/tr/
# 1890  https://www.blogger.com/followers.g?blogID=702...
# 1891  https://www.blogger.com/blog-post-reactions.g?...
#
# [5 rows x 24 columns]

# %%
df = pd.read_sql_table('http_requests', DB, index_col='id')
print('HTTP Requests')
df.tail()
# Out:
# HTTP Requests
#          crawl_id           visit_id                time_stamp  incognito  \
# id
# 24202  -381328783  -3657597582389542  2019-08-27T05:16:03.543Z          0
# 24203  -381328783  -3864711585478952  2019-08-27T05:16:19.108Z          0
# 24204  -381328783  -2318928383487469  2019-08-27T05:16:30.800Z          0
# 24205  -381328783  -3657597582389542  2019-08-27T05:16:03.565Z          0
# 24206  -381328783  -3864711585478952  2019-08-27T05:16:19.129Z          0
#
#                      extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 24202  984e13ed-0aff-457b-9bb5-8e3353b33c8f            112          1       1
# 24203  922525b4-248b-4443-bed9-c6f7a39dc56b             22          1       1
# 24204  026bee9b-f3d7-48d0-ac13-f74a8332dd4f             67          1       1
# 24205  984e13ed-0aff-457b-9bb5-8e3353b33c8f            131          1       1
# 24206  922525b4-248b-4443-bed9-c6f7a39dc56b             33          1       1
#
#        frame_id  parent_frame_id  ... post_body_raw  \
# id                                ...
# 24202         0               -1  ...
# 24203         0               -1  ...
# 24204         0               -1  ...
# 24205         0               -1  ...
# 24206         0               -1  ...
#
#                                                  headers is_XHR is_full_page  \
# id
# 24202  [["Host","roomimg.stream.highwebmedia.com"],["...      0            1
# 24203  [["Host","www.msgm.it"],["User-Agent","Mozilla...      0            1
# 24204  [["Host","3.bp.blogspot.com"],["User-Agent","M...      0            1
# 24205  [["Host","roomimg.stream.highwebmedia.com"],["...      0            1
# 24206  [["Host","www.msgm.it"],["User-Agent","Mozilla...      0            1
#
#       is_frame_load                   triggering_origin  \
# id
# 24202             0              http://xxx-live.webcam
# 24203             0                 https://www.msgm.it
# 24204             0  http://kittiecaptions.blogspot.com
# 24205             0              http://xxx-live.webcam
# 24206             0                 https://www.msgm.it
#
#                            loading_origin  \
# id
# 24202              http://xxx-live.webcam
# 24203                 https://www.msgm.it
# 24204  http://kittiecaptions.blogspot.com
# 24205              http://xxx-live.webcam
# 24206                 https://www.msgm.it
#
#                               loading_href  resource_type  frame_ancestors
# id
# 24202              http://xxx-live.webcam/          image               []
# 24203              https://www.msgm.it/en/     stylesheet               []
# 24204  http://kittiecaptions.blogspot.com/          image               []
# 24205              http://xxx-live.webcam/          image               []
# 24206              https://www.msgm.it/en/          image               []
#
# [5 rows x 26 columns]

# %%
df = pd.read_sql_table('http_responses', DB, index_col='id')
print('HTTP Responses')
df.tail()
# Out:
# HTTP Responses
#          crawl_id        visit_id                time_stamp  incognito  \
# id
# 1798  -1298079119  16111732508824  2019-08-27T06:34:26.703Z          0
# 1799  -1298079119  16111732508824  2019-08-27T06:34:26.963Z          0
# 1800  -1298079119  16111732508824  2019-08-27T06:34:27.143Z          0
# 1801  -1298079119  16111732508824  2019-08-27T06:34:26.766Z          0
# 1802  -1298079119  16111732508824  2019-08-27T06:34:26.967Z          0
#
#                     extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 1798  63e88529-adeb-4fb1-81ad-8800195254eb            889          1       1
# 1799  63e88529-adeb-4fb1-81ad-8800195254eb            891          1       1
# 1800  63e88529-adeb-4fb1-81ad-8800195254eb            893          1       1
# 1801  63e88529-adeb-4fb1-81ad-8800195254eb            890          1       1
# 1802  63e88529-adeb-4fb1-81ad-8800195254eb            892          1       1
#
#       frame_id request_id  is_cached  \
# id
# 1798         0        141          0
# 1799         0        145          0
# 1800         0        138          0
# 1801         0        136          0
# 1802         0        144          0
#
#                                                     url method  \
# id
# 1798  http://bastidirectory.com/images/post/15550414...    GET
# 1799  http://bastidirectory.com/images/post/15421037...    GET
# 1800  http://bastidirectory.com/images/post/15639408...    GET
# 1801  http://bastidirectory.com/images/post/15643317...    GET
# 1802  http://bastidirectory.com/images/post/15433782...    GET
#
#      response_status response_status_text  \
# id
# 1798             200      HTTP/1.1 200 OK
# 1799             200      HTTP/1.1 200 OK
# 1800             200      HTTP/1.1 200 OK
# 1801             200      HTTP/1.1 200 OK
# 1802             200      HTTP/1.1 200 OK
#
#                                                 headers location content_hash
# id
# 1798  [["Date","Tue, 27 Aug 2019 06:34:26 GMT"],["Se...
# 1799  [["Date","Tue, 27 Aug 2019 06:34:26 GMT"],["Se...
# 1800  [["Date","Tue, 27 Aug 2019 06:34:25 GMT"],["Se...
# 1801  [["Date","Tue, 27 Aug 2019 06:34:25 GMT"],["Se...
# 1802  [["Date","Tue, 27 Aug 2019 06:34:26 GMT"],["Se...

# %%
df = pd.read_sql_table('http_redirects', DB, index_col='id')
print('HTTP Redirects')
df.tail()
# Out:
# HTTP Redirects
#        crawl_id           visit_id                time_stamp  incognito  \
# id
# 56  -1298079119     16111732508824  2019-08-27T06:34:23.890Z          0
# 57  -1298079119     16111732508824  2019-08-27T06:34:23.875Z          0
# 58  -1298079119  -3403066401256025  2019-08-27T06:34:26.640Z          0
# 59  -1298079119   4443523029462590  2019-08-27T06:34:28.020Z          0
# 60  -1298079119   4443523029462590  2019-08-27T06:34:28.442Z          0
#
#                   extension_session_uuid  event_ordinal  window_id  tab_id  \
# id
# 56  63e88529-adeb-4fb1-81ad-8800195254eb            819          1       1
# 57  63e88529-adeb-4fb1-81ad-8800195254eb            815          1       1
# 58  06eb3d4d-9f0b-448f-9ed8-af715592d98c              1          1       1
# 59  d3f1160e-8ac9-4c1e-aaee-49c0f4e8a5cb              0          1       1
# 60  d3f1160e-8ac9-4c1e-aaee-49c0f4e8a5cb              3          1       1
#
#       frame_id old_request_id new_request_id  \
# id
# 56  4294967366            282           None
# 57  4294967366            280           None
# 58           0             14           None
# 59           0             13           None
# 60           0             13           None
#
#                                       old_request_url  \
# id
# 56  https://ssum-sec.casalemedia.com/usermatchredi...
# 57  https://image6.pubmatic.com/AdServer/UCookieSe...
# 58                                http://bunjang.net/
# 59                       http://compuseriestotal.com/
# 60                      https://compuseriestotal.com/
#
#                                       new_request_url response_status  \
# id
# 56  https://cm.g.doubleclick.net/pixel?google_nid=...             302
# 57  https://cm.g.doubleclick.net/pixel?google_nid=...             302
# 58                           https://m.bunjang.co.kr/             301
# 59                      https://compuseriestotal.com/             301
# 60                       https://compuseriestotal.me/             301
#
#               response_status_text
# id
# 56  HTTP/1.1 302 Moved Temporarily
# 57              HTTP/1.1 302 Found
# 58  HTTP/1.1 301 Moved Permanently
# 59  HTTP/1.1 301 Moved Permanently
# 60  HTTP/2.0 301 Moved Permanently

# %%
df = pd.read_sql_table('logs', DB, index_col='id')
print('Logs')
df.tail()
# Out:
# Logs
#                timestamp  msecs          name  level  \
# id
# 200  2019-08-27 01:34:17    809  WebExtension  DEBUG
# 201  2019-08-27 01:34:17    809  WebExtension  DEBUG
# 202  2019-08-27 01:34:17    804  WebExtension  DEBUG
# 203  2019-08-27 01:34:17    926       crawler   INFO
# 204  2019-08-27 01:34:18    127       crawler   INFO
#
#                                                message exception stack
# id
# 200                     Cookie instrumentation enabled      None  None
# 201                 Javascript instrumentation enabled      None  None
# 202                       HTTP Instrumentation enabled      None  None
# 203  GECKODRIVER 1566887657675\tMarionette\tWARN\tT...      None  None
# 204  GECKODRIVER 1566887657738\taddons.xpi\tWARN\tF...      None  None

# %%
# for message in df[df.message.str.startswith('GECKODRIVER')].message.values:
#    print(message)

# %% [markdown]
# ----

# %%
urls_with_js_cookies = pd.read_csv('/home/bird/Data/unique_urls_crawl.csv.gz', usecols=[1], names=['url'])
urls_with_js_cookies = urls_with_js_cookies.drop_duplicates()
urls_with_js_cookies.head()
# Out:
#                                       url
# 0           http://xn--cckr8mka9bt9h.shop
# 1  http://xn--u9jwfrb8ebi5a3tzee8630s.com
# 2  http://xn--zck9awe6d0523auwbp4rs9t.com
# 3                http://yoshida-shoin.com
# 4                 http://yoshinomayumi.jp

# %%
len(urls_with_js_cookies)
# Out:
# 8145

# %%
with open('sample_of_js_cookies_sites_200.csv', 'w') as f:
    f.write(json.dumps(urls_with_js_cookies.url.sample(n=200).to_list()))

# %%
# test load
urls = json.load(open('sample_of_js_cookies_sites_200.csv', 'r'))
urls[0:5]
# Out:
# ['http://sedisk.com',
#  'http://flow-festival.at',
#  'http://gameplorer.de',
#  'http://noticiasdatv.uol.com.br',
#  'http://bunjang.net']
